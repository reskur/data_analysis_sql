# %% [markdown]
# **LONDON CRIME DATA**
#
# This data counts the number of crimes at two different geographic levels of London (LSOA and borough) by year, according to crime type. Includes data from 2008 to present

# %% [markdown]
# **IMPORT BIGQUERY PACKAGE**

# %%
from google.cloud import bigquery

# %% [markdown]
# **MAKE A CLIENT OBJECT**

# %%
client = bigquery.Client()
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %% [markdown]
# **CONNECT TO LONDON CRIME DATASET**

# %%
dataset_ref = client.dataset('london_crime', project='bigquery-public-data')
dataset = client.get_dataset(dataset_ref)

# %% [markdown]
# **CHECK NUMBER OF TABLES IN THIS DATASET**

# %%
tables = list(client.list_tables(dataset))
for table in tables:
    print(table.table_id)
# Out:
# crime_by_lsoa

# %% [markdown]
# **CONNECT TO CRIME_BY_LSOA TABLE**

# %%
table_ref = dataset_ref.table('crime_by_lsoa')
table = client.get_table(table_ref)

# %%
table.schema
# Out:
# [SchemaField('lsoa_code', 'STRING', 'NULLABLE', 'Lower Layer Super Output Area code according to the Office for National Statistics', (), None),
#  SchemaField('borough', 'STRING', 'NULLABLE', '', (), None),
#  SchemaField('major_category', 'STRING', 'NULLABLE', '', (), None),
#  SchemaField('minor_category', 'STRING', 'NULLABLE', '', (), None),
#  SchemaField('value', 'INTEGER', 'NULLABLE', 'Summary of the number of crimes for the month', (), None),
#  SchemaField('year', 'INTEGER', 'NULLABLE', '', (), None),
#  SchemaField('month', 'INTEGER', 'NULLABLE', '', (), None)]

# %% [markdown]
# **EXPLORE CONTENT IN THIS TABLE, LET'S SEE THE FIRST 10 ROWS**

# %%
client.list_rows(table, max_results=10).to_dataframe()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Cannot use bqstorage_client if max_results is set, reverting to fetching data with the tabledata.list endpoint.
#   """Entry point for launching an IPython kernel.
#    lsoa_code borough   major_category minor_category  value  year  month
# 0  E01000478   Brent  Sexual Offences           Rape      0  2008      1
# 1  E01000619   Brent  Sexual Offences           Rape      1  2008      1
# 2  E01000619   Brent  Sexual Offences           Rape      0  2008      7
# 3  E01000156  Barnet  Sexual Offences           Rape      0  2008     11
# 4  E01000156  Barnet  Sexual Offences           Rape      0  2008      7
# 5  E01000384  Bexley  Sexual Offences           Rape      1  2008      1
# 6  E01001301  Ealing  Sexual Offences           Rape      1  2008      1
# 7  E01001295  Ealing  Sexual Offences           Rape      0  2008      1
# 8  E01000291  Barnet  Sexual Offences           Rape      0  2008      8
# 9  E01000630   Brent  Sexual Offences           Rape      1  2008      2

# %% [markdown]
# **LET'S SEE HOW MANY BOROUGH THIS DATASET CONTAINED**

# %%
query = """
        SELECT borough
        FROM `bigquery-public-data.london_crime.crime_by_lsoa`
        GROUP BY borough
        ORDER BY borough
        """
result = client.query(query).result().to_dataframe()
result.head(50)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#                    borough
# 0     Barking and Dagenham
# 1                   Barnet
# 2                   Bexley
# 3                    Brent
# 4                  Bromley
# 5                   Camden
# 6           City of London
# 7                  Croydon
# 8                   Ealing
# 9                  Enfield
# 10               Greenwich
# 11                 Hackney
# 12  Hammersmith and Fulham
# 13                Haringey
# 14                  Harrow
# 15                Havering
# 16              Hillingdon
# 17                Hounslow
# 18               Islington
# 19  Kensington and Chelsea
# 20    Kingston upon Thames
# 21                 Lambeth
# 22                Lewisham
# 23                  Merton
# 24                  Newham
# 25               Redbridge
# 26    Richmond upon Thames
# 27               Southwark
# 28                  Sutton
# 29           Tower Hamlets
# 30          Waltham Forest
# 31              Wandsworth
# 32             Westminster

# %% [markdown]
# **WHEN IS THIS DATA COLLECTED AND WHEN IS THE LAST DATA RECORDED**

# %%
query = """
        SELECT MIN(year) start_year, MAX(year) end_year
        FROM `bigquery-public-data.london_crime.crime_by_lsoa`
        """
result = client.query(query).to_dataframe()
result.head()
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#    start_year  end_year
# 0        2008      2016

# %% [markdown]
# **WHICH BOROUGH HAS THE MOST NUMBER OF CRIMINAL CASES FROM 2008 TO 2016**

# %%
query = """
        SELECT borough, SUM(value) tot_crime
        FROM `bigquery-public-data.london_crime.crime_by_lsoa`
        GROUP BY borough
        ORDER BY tot_crime DESC
        """
result = client.query(query).to_dataframe()
result.head(10)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#          borough  tot_crime
# 0    Westminster     455028
# 1        Lambeth     292178
# 2      Southwark     278809
# 3         Camden     275147
# 4         Newham     262024
# 5        Croydon     260294
# 6         Ealing     251562
# 7      Islington     230286
# 8  Tower Hamlets     228613
# 9          Brent     227551

# %% [markdown]
# **WHAT MONTH IN A BOROUGH RECORDED A HIGHER NUMBER OF CRIMINAL CASES COMPARED TO OTHER TIMES**

# %%
query = """
        WITH time_crimes AS (
        SELECT borough, month, year, SUM(value) tot_num
        FROM `bigquery-public-data.london_crime.crime_by_lsoa`
        GROUP BY borough, month, year
        )
        SELECT *
        FROM time_crimes
        WHERE tot_num = (
            SELECT MAX(tot_num)
            FROM time_crimes AS tc
            WHERE time_crimes.borough = tc.borough
        )
        ORDER BY tot_num DESC
        """
result = client.query(query).to_dataframe()
result.head(35)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#                    borough  month  year  tot_num
# 0              Westminster      7  2012     5428
# 1                   Camden      3  2011     3196
# 2                  Lambeth      7  2016     3161
# 3                Southwark      6  2008     3116
# 4                   Ealing      7  2010     2996
# 5                  Croydon      1  2012     2970
# 6                   Newham      1  2008     2876
# 7            Tower Hamlets      7  2016     2783
# 8                    Brent     10  2011     2625
# 9                  Hackney      6  2016     2625
# 10               Islington      7  2016     2569
# 11                Haringey      7  2016     2444
# 12                Lewisham      5  2008     2426
# 13  Kensington and Chelsea      8  2016     2398
# 14              Wandsworth      3  2012     2387
# 15          Waltham Forest      6  2009     2373
# 16              Hillingdon     12  2016     2300
# 17                  Barnet     11  2012     2264
# 18                 Bromley      5  2009     2147
# 19                Hounslow      1  2012     2134
# 20                Hounslow     10  2016     2134
# 21                 Enfield      1  2008     2121
# 22               Greenwich      1  2008     2093
# 23               Redbridge     10  2011     2026
# 24  Hammersmith and Fulham      7  2010     2020
# 25    Barking and Dagenham      3  2009     1712
# 26                Havering      3  2012     1532
# 27                  Bexley     11  2008     1373
# 28                  Harrow      6  2010     1322
# 29                  Merton      7  2008     1277
# 30                  Sutton      6  2009     1206
# 31    Richmond upon Thames      5  2012     1134
# 32    Kingston upon Thames      3  2008      985
# 33          City of London     12  2016       34

# %% [markdown]
# **FROM 2008 TO 2016 IN LONDON WHAT CRIMES PRINTED THE MOST NUMBER OF CASES**

# %%
query = """
        SELECT major_category, minor_category, SUM(value) num_crimes
        FROM `bigquery-public-data.london_crime.crime_by_lsoa`
        GROUP BY major_category, minor_category
        ORDER BY num_crimes DESC
        """
result = client.query(query).to_dataframe()
result.head(10)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#                 major_category                    minor_category  num_crimes
# 0           Theft and Handling                       Other Theft      980085
# 1           Theft and Handling          Theft From Motor Vehicle      569956
# 2                     Burglary            Burglary in a Dwelling      491282
# 3  Violence Against the Person                        Harassment      458124
# 4  Violence Against the Person               Assault with Injury      451001
# 5                        Drugs               Possession Of Drugs      431948
# 6  Violence Against the Person                    Common Assault      413690
# 7           Theft and Handling                  Theft From Shops      345142
# 8           Theft and Handling                Other Theft Person      308842
# 9              Criminal Damage  Criminal Damage To Motor Vehicle      265463

# %% [markdown]
# **WE WILL SORT THE CRIMES IN A BOROUGH BASED ON THE NUMBER OF CASES AND WILL DISPLAY THE THREE CRIMES WITH THE LARGEST NUMBER IN THAT AREA**

# %%
query = """
        SELECT borough, major_category, rank_per_borough, num_accident
        FROM(
            SELECT borough, major_category,
                RANK () OVER(PARTITION BY borough ORDER BY SUM(value) DESC) AS rank_per_borough,
                SUM(value) AS num_accident
            FROM `bigquery-public-data.london_crime.crime_by_lsoa`
            GROUP BY borough, major_category
        )
        WHERE rank_per_borough <= 3
        ORDER BY borough, rank_per_borough
        """
result = client.query(query).to_dataframe()
result.head(15)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#                  borough               major_category  rank_per_borough  \
# 0   Barking and Dagenham           Theft and Handling                 1
# 1   Barking and Dagenham  Violence Against the Person                 2
# 2   Barking and Dagenham              Criminal Damage                 3
# 3                 Barnet           Theft and Handling                 1
# 4                 Barnet  Violence Against the Person                 2
# 5                 Barnet                     Burglary                 3
# 6                 Bexley           Theft and Handling                 1
# 7                 Bexley  Violence Against the Person                 2
# 8                 Bexley              Criminal Damage                 3
# 9                  Brent           Theft and Handling                 1
# 10                 Brent  Violence Against the Person                 2
# 11                 Brent                     Burglary                 3
# 12               Bromley           Theft and Handling                 1
# 13               Bromley  Violence Against the Person                 2
# 14               Bromley                     Burglary                 3
#
#     num_accident
# 0          50999
# 1          43091
# 2          18888
# 3          87285
# 4          46565
# 5          36981
# 6          40071
# 7          30037
# 8          17244
# 9          72523
# 10         63178
# 11         28923
# 12         69742
# 13         46759
# 14         27135

# %% [markdown]
# **DOES THE EVENT OF CRIME IN EACH BOROUGH HAVE INCREASED OR DECREASED EVERY YEAR?**

# %%
query = """
        SELECT borough,
            SUM(IF(year = 2008, value, 0)) tot_crimes_08,
            SUM(IF(year = 2009, value, 0)) tot_crimes_09,
            SUM(IF(year = 2010, value, 0)) tot_crimes_10,
            SUM(IF(year = 2011, value, 0)) tot_crimes_11,
            SUM(IF(year = 2012, value, 0)) tot_crimes_12,
            SUM(IF(year = 2013, value, 0)) tot_crimes_13,
            SUM(IF(year = 2014, value, 0)) tot_crimes_14,
            SUM(IF(year = 2015, value, 0)) tot_crimes_15,
            SUM(IF(year = 2016, value, 0)) tot_crimes_16
        FROM `bigquery-public-data.london_crime.crime_by_lsoa`
        GROUP BY borough
        ORDER BY borough 
        """
result = client.query(query).to_dataframe()
result.head(35)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#                    borough  tot_crimes_08  tot_crimes_09  tot_crimes_10  \
# 0     Barking and Dagenham          17656          17713          17130
# 1                   Barnet          23944          23449          23416
# 2                   Bexley          15305          14445          13166
# 3                    Brent          23504          24748          25512
# 4                  Bromley          24015          21858          19572
# 5                   Camden          32010          31612          31804
# 6           City of London              0              0              0
# 7                  Croydon          29516          29784          29373
# 8                   Ealing          28947          28617          31360
# 9                  Enfield          21980          21147          20808
# 10               Greenwich          22010          19851          18626
# 11                 Hackney          22004          20718          20175
# 12  Hammersmith and Fulham          21114          21211          21941
# 13                Haringey          25724          23704          22156
# 14                  Harrow          13774          13948          13945
# 15                Havering          15395          14538          14957
# 16              Hillingdon          24318          24605          23421
# 17                Hounslow          20204          19783          19665
# 18               Islington          26273          25485          24693
# 19  Kensington and Chelsea          20663          18742          19481
# 20    Kingston upon Thames          10661          10163          10171
# 21                 Lambeth          31717          31225          31671
# 22                Lewisham          27054          25182          24532
# 23                  Merton          13875          13561          13595
# 24                  Newham          29752          28610          30728
# 25               Redbridge          20873          20837          20652
# 26    Richmond upon Thames          11106          10618          10601
# 27               Southwark          33470          30623          31320
# 28                  Sutton          12943          12240          12032
# 29           Tower Hamlets          23578          21959          23072
# 30          Waltham Forest          24080          24761          24818
# 31              Wandsworth          23330          23021          22815
# 32             Westminster          47846          48456          48116
#
#     tot_crimes_11  tot_crimes_12  tot_crimes_13  tot_crimes_14  tot_crimes_15  \
# 0           16686          15990          15759          15426          16346
# 1           24007          23573          22510          22572          24036
# 2           11325          11669          11552          11844          11990
# 3           27669          26357          23759          24426          24883
# 4           19868          19622          18945          19668          20637
# 5           33956          31472          28435          27198          29477
# 6              69            157            110            115            151
# 7           29830          30189          27444          27357          28089
# 8           29537          28832          25917          24978          26247
# 9           21041          21069          21574          21700          22076
# 10          18552          20028          18948          19894          20929
# 11          21395          27095          25633          24893          26941
# 12          22151          21030          18605          19185          19848
# 13          23179          23231          20705          22773          24626
# 14          12801          12803          11914          11909          12601
# 15          15496          15965          15089          14734          15870
# 16          24282          22103          20248          23128          23234
# 17          21105          22724          19749          20005          21286
# 18          24980          26268          23784          24679          27032
# 19          19146          19757          17702          17840          19070
# 20          10155           9956           9191           9288           9738
# 21          33224          33473          31868          31765          33164
# 22          24201          23652          22074          21101          23437
# 23          13548          12856          11595          11596          12273
# 24          27978          30067          27577          28005          29217
# 25          21994          21424          19793          19590          18897
# 26          10896          11168          10439          10456          10413
# 27          30723          30737          31128          28912          30260
# 28          11068          10948          10057          10443          10598
# 29          24712          26784          26258          25504          27493
# 30          23714          22647          21903          20271          20969
# 31          21384          24457          22290          21364          22401
# 32          54243          59226          53852          47564          47395
#
#     tot_crimes_16
# 0           16741
# 1           24684
# 2           12840
# 3           26693
# 4           20164
# 5           29183
# 6             178
# 7           28712
# 8           27127
# 9           22485
# 10          22730
# 11          28265
# 12          20174
# 13          27174
# 14          13153
# 15          16903
# 16          24341
# 17          22251
# 18          27092
# 19          19580
# 20           9983
# 21          34071
# 22          23904
# 23          12755
# 24          30090
# 25          19502
# 26          11074
# 27          31636
# 28          10658
# 29          29253
# 30          20716
# 31          23679
# 32          48330

# %% [markdown]
# **WHAT CRIMES HAVE INCREASED AND DECREASED NUMBER OF CASE COMPARED IN 2008 WITH 2016 AND HOW MUCH CHANGES THE NUMBER OF CASES**

# %%
query = """
        SELECT major_category, minor_category, tot_crime_08, tot_crime_16,
        tot_crime_16 - tot_crime_08 AS change,
        ROUND(((tot_crime_16 - tot_crime_08)/tot_crime_16)*100,2) perc_change
        FROM(
            SELECT major_category, minor_category,
                SUM(IF(year = 2008, value, null)) AS tot_crime_08,
                SUM(IF(year = 2016, value, null)) AS tot_crime_16
            FROM `bigquery-public-data.london_crime.crime_by_lsoa`
            WHERE value > 0
            GROUP BY major_category, minor_category
        )
        ORDER BY perc_change DESC
        """
result = client.query(query).to_dataframe()
result.head(35)
# Out:
# /opt/conda/lib/python3.7/site-packages/google/cloud/bigquery/client.py:440: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
#                  major_category                          minor_category  \
# 0            Theft and Handling  Motor Vehicle Interference & Tampering
# 1   Violence Against the Person                            Wounding/GBH
# 2   Violence Against the Person                              Harassment
# 3   Violence Against the Person                          Common Assault
# 4     Other Notifiable Offences                        Other Notifiable
# 5            Theft and Handling                        Theft From Shops
# 6            Theft and Handling                      Other Theft Person
# 7   Violence Against the Person                          Other violence
# 8            Theft and Handling             Theft/Taking of Pedal Cycle
# 9            Theft and Handling                             Other Theft
# 10              Criminal Damage                   Other Criminal Damage
# 11    Other Notifiable Offences                          Going Equipped
# 12           Theft and Handling           Theft/Taking Of Motor Vehicle
# 13  Violence Against the Person                     Assault with Injury
# 14                        Drugs                             Other Drugs
# 15  Violence Against the Person                        Offensive Weapon
# 16                        Drugs                        Drug Trafficking
# 17                     Burglary             Burglary in Other Buildings
# 18                      Robbery                       Personal Property
# 19  Violence Against the Person                                  Murder
# 20                     Burglary                  Burglary in a Dwelling
# 21              Criminal Damage       Criminal Damage To Other Building
# 22           Theft and Handling                Theft From Motor Vehicle
# 23              Criminal Damage        Criminal Damage To Motor Vehicle
# 24              Criminal Damage             Criminal Damage To Dwelling
# 25           Theft and Handling                   Handling Stolen Goods
# 26                      Robbery                       Business Property
# 27                        Drugs                     Possession Of Drugs
# 28              Sexual Offences                                    Rape
# 29              Sexual Offences                            Other Sexual
# 30             Fraud or Forgery                      Counted per Victim
# 31             Fraud or Forgery                   Other Fraud & Forgery
#
#     tot_crime_08  tot_crime_16   change  perc_change
# 0           3868       11438.0   7570.0        66.18
# 1           8701       23525.0  14824.0        63.01
# 2          43389       78676.0  35287.0        44.85
# 3          37356       64440.0  27084.0        42.03
# 4           9491       15205.0   5714.0        37.58
# 5          32857       46957.0  14100.0        30.03
# 6          24453       34868.0  10415.0        29.87
# 7           7721       10588.0   2867.0        27.08
# 8          15895       18001.0   2106.0        11.70
# 9          99280      103807.0   4527.0         4.36
# 10         17649       17633.0    -16.0        -0.09
# 11           621         604.0    -17.0        -2.81
# 12         28303       26366.0  -1937.0        -7.35
# 13         56586       50038.0  -6548.0       -13.09
# 14           373         319.0    -54.0       -16.93
# 15          5961        5013.0   -948.0       -18.91
# 16          4203        3392.0   -811.0       -23.91
# 17         31437       25289.0  -6148.0       -24.31
# 18         26663       20874.0  -5789.0       -27.73
# 19           130         101.0    -29.0       -28.71
# 20         56655       42996.0 -13659.0       -31.77
# 21          9011        6700.0  -2311.0       -34.49
# 22         76570       51319.0 -25251.0       -49.20
# 23         41693       25787.0 -15906.0       -61.68
# 24         23519       13951.0  -9568.0       -68.58
# 25          2466        1377.0  -1089.0       -79.08
# 26          2964        1654.0  -1310.0       -79.20
# 27         64228       35203.0 -29025.0       -82.45
# 28           268           NaN      NaN          NaN
# 29          1005           NaN      NaN          NaN
# 30          3840           NaN      NaN          NaN
# 31          1485           NaN      NaN          NaN
